# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('VideoSegment.csv')  
df[df.]
# Out:
#       Id  PatientTaskHandMappingId  SegmentId  Start  End  \
# 0      1                         1          1     75  111
# 1      2                         1          2     92  111
# 2      3                         1          3    111  139
# 3      4                         1          4    138  169
# 4      5                         9          1     65  112
# ..   ...                       ...        ...    ...  ...
# 417  418                       219          6     81  175
# 418  419                       239          1      1    1
# 419  420                       239          2      1    1
# 420  421                       239          3      1    1
# 421  422                       239          4      1    1
#
#                        CreatedAt                    UpdatedAt
# 0    2022-11-29 06:34:16.3254527  2023-02-01 01:49:10.8866201
# 1    2022-11-29 06:34:16.3921381  2023-02-01 01:49:10.9053986
# 2    2022-11-29 06:34:16.4006869  2023-02-01 01:49:10.9148124
# ...

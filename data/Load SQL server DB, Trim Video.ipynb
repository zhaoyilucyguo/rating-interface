# %%
import pyodbc
import pandas as pd
import numpy as np
import cv2
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.video.io.VideoFileClip import VideoFileClip

# %% [markdown]
# ## Setup Python SQL Server Connection

# %%
#Setup Python SQL Server Connection
cnxn_str = ("Driver={ODBC Driver 17 for SQL Server};"
            "Server=.;"
            "Database=inr-docker-primary;"
            "Trusted_Connection=yes;")
cnxn = pyodbc.connect(cnxn_str)

# %%
#Run an SQL Query
cursor = cnxn.cursor()

# %%
FileInformation = pd.read_sql("SELECT * FROM FileInformation", cnxn)
VideoSegment = pd.read_sql("SELECT * FROM VideoSegment", cnxn)

# %%
FileInformation
# Out:
#         Id                                    FileName  \
# 0        1    ARAT_02_left_Impaired_cam2_activity2.mp4
# 1        2   ARAT_05_left_Impaired_cam1_activity17.mp4
# 2        3    ARAT_03_left_Impaired_cam1_activity9.mp4
# 3        4   ARAT_06_left_Impaired_cam3_activity11.mp4
# 4        5   ARAT_09_right_Impaired_cam2_activity6.mp4
# ...    ...                                         ...
# 1264  1265   ARAT_013_left_Impaired_cam1_activity1.mp4
# 1265  1266  ARAT_010_left_Impaired_cam4_activity15.mp4
# 1266  1267  ARAT_010_left_Impaired_cam3_activity17.mp4
# 1267  1268    ARAT_06_left_Impaired_cam2_activity3.mp4
# 1268  1269  ARAT_08_left_Unimpaired_cam4_activity1.mp4
#
#       PatientTaskHandmappingId  CameraId
# 0                            1         2
# 1                            2         1
# 2                            3         1
# 3                            4         3
# 4                            5         2
# ...                        ...       ...
# ...

# %%
Segment = pd.read_sql("SELECT * FROM Segment", cnxn)
Segment
# Out:
#    Id  Name
# 0   1    IP
# 1   2     T
# 2   3  MTR1
# 3   4    PR
# 4   5  MTR2
# 5   6    TG
# 6   7    GI
# 7   9    GT

# %%
dic = {}
for i in np.arange(Segment.shape[0]):
    seg = Segment.iloc[i]
    dic[seg.Id]=seg.Name
dic[7]='GIP'
dic
# Out:
# {1: 'IP', 2: 'T', 3: 'MTR1', 4: 'PR', 5: 'MTR2', 6: 'TG', 7: 'GIP', 9: 'GT'}

# %%
newfolder = '..\\public\\TrimmedVideos\\'
folder = '..\\public\\Videos\\'
vid=cv2.VideoCapture(folder+'ARAT_02_left_Impaired_cam2_activity2.mp4')
vid.isOpened()
# Out:
# True

# %%
newfolder = '..\\public\\TrimmedVideos\\'
folder = '..\\public\\Videos\\'
corrupted_videos = []
df = pd.DataFrame()
for i in np.arange(VideoSegment.shape[0]):
    vs = VideoSegment.iloc[i]
    pthId = vs.PatientTaskHandMappingId
    segId = vs.SegmentId
    start_frame = vs.Start
    end_frame = vs.End
    fi = FileInformation[FileInformation.PatientTaskHandmappingId == pthId]
    for j in np.arange(fi.shape[0]):
        file = fi.iloc[j]
        video = file.FileName
        camId = file.CameraId
        # Load the video file
        clip = VideoFileClip(folder+video)
        if (clip.duration):
            # Calculate the start and end times in seconds
            start_time = start_frame / clip.fps
            end_time = end_frame / clip.fps
            # Extract the subclip
            subclip = clip.subclip(start_time, end_time)
            # Save the subclip to a new file
            ffmpeg_extract_subclip(folder+video, start_time, end_time, targetname=newfolder+dic[segId]+"_"+video)
        
            row = {'SegmentId': segId, 
                   'PatientTaskHandMappingId': pthId, 
                   'CameraId': camId, 
                   'FileName': dic[segId] + "_" + video}
            #df = df.append(row, ignore_index = True)
        else: #corrupted file
            corrupted_videos.append(video)
df
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# ...

# %%
insert_query = '''SET IDENTITY_INSERT SegmentFileInformation ON
INSERT INTO SegmentFileInformation (Id, FileName, PatientTaskHandMappingId, CameraId, SegmentId)
                  VALUES (?, ?, ?, ?, ?)'''
for i in np.arange(df.shape[0]):
        row = df.iloc[i]
        values = (int(i+1), row.FileName, int(row.PatientTaskHandMappingId), int(row.CameraId), int(row.SegmentId))
        cursor.execute(insert_query, values)

# %%
cnxn.commit()
cursor.close()
cnxn.close()

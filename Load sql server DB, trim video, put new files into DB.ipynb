# %%
import pyodbc
import pandas as pd
import numpy as np
import cv2
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %% [markdown]
# ## Setup Python SQL Server Connection

# %%
#Setup Python SQL Server Connection
cnxn_str = ("Driver={ODBC Driver 17 for SQL Server};"
            "Server=(LocalDB)\MSSQLLocalDB;"
            "Database=inr_db_primary;"
            "Trusted_Connection=yes;")
cnxn = pyodbc.connect(cnxn_str)

# %%
#Run an SQL Query
cursor = cnxn.cursor()

# %%
FileInformation = pd.read_sql("SELECT * FROM FileInformation", cnxn)
VideoSegment = pd.read_sql("SELECT * FROM VideoSegment", cnxn)

# %%
dic = {
    1: "IPT",
    2:  "ET",
    3: "M&TR",
    6: "TG",
    5: "M&TR_2",
    4: "P&R",
    7: "GI",
    8: "GP"
}

# %%
dic[8]
# Out:
# 'GP'

# %%
folder = 'public\\Videos\\'
#corrupted_videos = []
df = pd.DataFrame()
for i in np.arange(VideoSegment.shape[0]):
    vs = VideoSegment.iloc[i]
    pthId = vs.PatientTaskHandMappingId
    segId = vs.SegmentId
    start = round(vs.Start/30, 3)
    end = round(vs.End/30, 3)
    fi = FileInformation[FileInformation.PatientTaskHandmappingId == pthId]
    for j in np.arange(fi.shape[0]):
        file = fi.iloc[j]
        video = file.FileName
        camId = file.CameraId
        print(pthId, video, start, end)
        vid = cv2.VideoCapture(folder+video)
        if vid.isOpened():
            #ffmpeg_extract_subclip(folder+video, start, end+1, targetname=folder+dic[segId]+"_"+video)
            row = {'SegmentId': segId, 
                   'PatientTaskHandMappingId': pthId, 
                   'CameraId': camId, 
                   'FileName': dic[segId] + "_" + video}
            df = df.append(row, ignore_index = True)
        else: #corrupted file
            corrupted_videos.append(video)
df
# Out:
# 1 ARAT_02_left_Impaired_cam2_activity2.mp4 2.5 3.7
# 1 ARAT_02_left_Impaired_cam1_activity2.mp4 2.5 3.7
# 1 ARAT_02_left_Impaired_cam4_activity2.mp4 2.5 3.7
# 1 ARAT_02_left_Impaired_cam3_activity2.mp4 2.5 3.7
# 1 ARAT_02_left_Impaired_cam2_activity2.mp4 3.067 3.7
# 1 ARAT_02_left_Impaired_cam1_activity2.mp4 3.067 3.7
# 1 ARAT_02_left_Impaired_cam4_activity2.mp4 3.067 3.7
# 1 ARAT_02_left_Impaired_cam3_activity2.mp4 3.067 3.7
# 1 ARAT_02_left_Impaired_cam2_activity2.mp4 3.7 4.633
# 1 ARAT_02_left_Impaired_cam1_activity2.mp4 3.7 4.633
# 1 ARAT_02_left_Impaired_cam4_activity2.mp4 3.7 4.633
# 1 ARAT_02_left_Impaired_cam3_activity2.mp4 3.7 4.633
# 1 ARAT_02_left_Impaired_cam2_activity2.mp4 4.6 5.633
# 1 ARAT_02_left_Impaired_cam1_activity2.mp4 4.6 5.633
# 1 ARAT_02_left_Impaired_cam4_activity2.mp4 4.6 5.633
# 1 ARAT_02_left_Impaired_cam3_activity2.mp4 4.6 5.633
# 9 ARAT_02_left_Impaired_cam4_activity1.mp4 2.167 3.733
# 9 ARAT_02_left_Impaired_cam1_activity1.mp4 2.167 3.733
# ...

# %%
corrupted_videos
# Out:
# ['ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_02_left_Impaired_cam2_activity18 .mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam3_activity18.mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4',
#  'ARAT_09_right_Impaired_cam2_activity5 .mp4']

# %%
insert_query = '''INSERT INTO SegmentFileInformation (id, FileName, PatientTaskHandMappingId, CameraId, SegmentId)
                  VALUES (?, ?, ?, ?, ?)'''
for i in np.arange(df.shape[0]):
        row = df.iloc[i]
        values = (int(i+1), row.FileName, int(row.PatientTaskHandMappingId), int(row.CameraId), int(row.SegmentId))
        cursor.execute(insert_query, values)

# %%
cnxn.commit()
cursor.close()
cnxn.close()
